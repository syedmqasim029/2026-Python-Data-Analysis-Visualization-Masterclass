# %% [markdown]
# ### Categorica Scatter Plot

# %% [markdown]
# #### Strip plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.style.use('fivethirtyeight')

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.catplot(x="day", y="tip", data=tips,kind='strip',hue='day')
plt.show()

# %%
sns.catplot(x="day", y="tip", data=tips,kind='strip',jitter=0.1,hue='day',palette='rocket_r')
plt.show()

# %%
sns.catplot(x="day", y="tip", data=tips,kind='swarm',hue='day')
plt.show()
# Out:
# /Users/tabindahasif/Library/Python/3.9/lib/python/site-packages/seaborn/categorical.py:3399: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/tabindahasif/Library/Python/3.9/lib/python/site-packages/seaborn/categorical.py:3399: UserWarning: 6.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(x="day", y="tip", data=tips,kind='swarm',hue='sex',palette='rocket_r')
plt.show()
# Out:
# /Users/tabindahasif/Library/Python/3.9/lib/python/site-packages/seaborn/categorical.py:3399: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/tabindahasif/Library/Python/3.9/lib/python/site-packages/seaborn/categorical.py:3399: UserWarning: 6.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
